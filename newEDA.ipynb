# %%
import numpy as np
import pandas as pd
import seaborn as sns
import ast, json

from datetime import datetime
import matplotlib.pyplot as plt

df = pd.read_csv("Train.csv")

df.head().T
# Out:
#                                                        0               1  \
# Order No                                   Order_No_4211  Order_No_25375
# User Id                                      User_Id_633    User_Id_2285
# Vehicle Type                                        Bike            Bike
# Platform Type                                          3               3
# Personal or Business                            Business        Personal
# Placement - Day of Month                               9              12
# Placement - Weekday (Mo = 1)                           5               5
# Placement - Time                              9:35:46 AM     11:16:16 AM
# Confirmation - Day of Month                            9              12
# Confirmation - Weekday (Mo = 1)                        5               5
# Confirmation - Time                           9:40:10 AM     11:23:21 AM
# Arrival at Pickup - Day of Month                       9              12
# ...

# %%
df.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# ...

# %%
df['Vehicle Type'].unique()
# Out:
# array(['Bike'], dtype=object)

# %%
# Dropped vehicle type because they were only bike
df = df.drop(['Vehicle Type'], axis=1)
df.shape
# Out:
# (21201, 28)

# %%
plot = sns.distplot(df['Time from Pickup to Arrival'], kde=False, color='b')

# %%
sns.boxplot(df['Time from Pickup to Arrival'])

# %%
#comparing personal and business customers
sns.countplot(y = df['Personal or Business']);

# %%
#types of platforms.
sns.countplot(y = df['Platform Type']);

#3 is mostly used

# %%
import missingno as msno

msno.matrix(df);

# %%
df = df.dropna()

# %%
ax = sns.scatterplot(x="Temperature", y="Time from Pickup to Arrival", data=df, hue = "Personal or Business")
